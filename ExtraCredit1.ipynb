# %%
import numpy as np
import matplotlib.pyplot as plt

xs=0.6
ys=1.1

#The following code generates 2 lists of pseudo-random numbers.
x= np.random.normal(loc=7.5, scale=xs, size=30000)
y= np.random.normal(loc=3.9, scale=ys, size=30000)

num_bins = 300
fullrange = [0,12]
height, bins, patches = plt.hist([x,y], num_bins, fullrange, histtype = "barstacked", color=["tab:blue","red"], alpha= 1.0)
#print(height)
#print(bins)
#print(patches)

#print(np.mean(x))
#print(np.median(x))
print(np.std(x))
#print(np.min(x))
#print(np.max(x))

#print(np.mean(y)
#print(np.median(y))
print(np.std(y))
#print(np.min(y))
#print(np.max(y))

# Adding labels to the axes
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.show()
# Out:
# 0.597952635973996
# 1.0925227392793753
